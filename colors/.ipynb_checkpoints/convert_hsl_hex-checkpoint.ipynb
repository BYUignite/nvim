# %%
from colorcycle import *

# %%
h = 200
s = np.array([70,60,50,40,30,20,20,20,20,20,20,20,20])
l = np.array([ 6,14,22,30,38,46,54,62,70,78,86,94,96])

hex = []
for i in range(len(l)):
    hex.append( hsl_to_hex(f"hsl({h}, {s[i]}%, {l[i]}%)") )

hex
# Out:
# ['#05131A',
#  '#0E2B39',
#  '#1C4154',
#  '#2E576B',
#  '#446B7E',
#  '#5E7D8D',
#  '#7292A1',
#  '#8BA5B1',
#  '#A3B8C2',
#  '#BCCBD2',
#  '#D4DEE2',
#  '#EDF1F3',
#  '#F3F5F7']

# %%
h = np.arange(20,360,30)
s = 90
l = 30

hex = []
for i in range(len(h)):
    hex.append( hsl_to_hex(f"hsl({h[i]}, {s}%, {l}%)") )

hex
# Out:
# ['#913608',
#  '#917A08',
#  '#639108',
#  '#1F9108',
#  '#089136',
#  '#08917A',
#  '#086391',
#  '#081F91',
#  '#360891',
#  '#7A0891',
#  '#910863',
#  '#91081F']

# %%
h = np.arange(20,360,30)
s = 50
l = 50

hex = []
for i in range(len(h)):
    hex.append( hsl_to_hex(f"hsl({h[i]}, {s}%, {l}%)") )

hex
# Out:
# ['#BF6A40',
#  '#BFAA40',
#  '#95BF40',
#  '#55BF40',
#  '#40BF6A',
#  '#40BFAA',
#  '#4095BF',
#  '#4055BF',
#  '#6A40BF',
#  '#AA40BF',
#  '#BF4095',
#  '#BF4055']
